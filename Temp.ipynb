# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("Data/Citywide_Payroll_Data__Fiscal_Year_.csv")
data.head()
# Out:
# C:\Users\lzhao\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Fiscal Year  Payroll Number                     Agency Name  Last Name  \
# 0         2020            17.0  OFFICE OF EMERGENCY MANAGEMENT    BEREZIN
# 1         2020            17.0  OFFICE OF EMERGENCY MANAGEMENT     GEAGER
# 2         2020            17.0  OFFICE OF EMERGENCY MANAGEMENT     RAMANI
# 3         2020            17.0  OFFICE OF EMERGENCY MANAGEMENT      ROTTA
# 4         2020            17.0  OFFICE OF EMERGENCY MANAGEMENT  WILSON II
#
#   First Name Mid Init Agency Start Date Work Location Borough  \
# 0    MIKHAIL      NaN        08/10/2015              BROOKLYN
# 1   VERONICA        M        09/12/2016              BROOKLYN
# 2   SHRADDHA      NaN        02/22/2016              BROOKLYN
# ...

# %%
data.shape
# Out:
# (4496767, 17)

# %%
data.sort_values("Base Salary", ascending=False).head()
# Out:
#          Fiscal Year  Payroll Number             Agency Name    Last Name  \
# 534088          2020           996.0   NYC HOUSING AUTHORITY         RUSS
# 3923291         2021           996.0   NYC HOUSING AUTHORITY         RUSS
# 3923347         2021           742.0  DEPT OF ED PEDAGOGICAL     CARRANZA
# 3923490         2021           742.0  DEPT OF ED PEDAGOGICAL  ROSS PORTER
# 157694          2020           742.0  DEPT OF ED PEDAGOGICAL     CARRANZA
#
#         First Name Mid Init Agency Start Date Work Location Borough  \
# 534088     GREGORY        P        08/12/2019             MANHATTAN
# 3923291    GREGORY        P        08/12/2019             MANHATTAN
# 3923347    RICHARD        A        04/02/2018             MANHATTAN
# 3923490     MEISHA        S        09/04/2001             MANHATTAN
# 157694     RICHARD        A        04/02/2018             MANHATTAN
#
#                 Title Description Leave Status as of June 30  Base Salary  \
# ...
